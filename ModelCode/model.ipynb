# %%
from keras.layers import Dense, Flatten, Activation, MaxPool2D, Conv2D
from keras.models import Sequential
import numpy as np
import pickle

X = np.array(pickle.load(open("X.pickle", "rb")))
y = np.array(pickle.load(open("y.pickle", "rb")))

X = X/255.0

model = Sequential()

model.add(Conv2D(64, (3,3), input_shape=X.shape[1:]))
model.add(Activation("relu"))
model.add(MaxPool2D(3,3))

model.add(Conv2D(128, (3,3)))
model.add(Activation("relu"))
model.add(MaxPool2D(3,3))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

model.add(Dense(64))
model.add(Activation("softmax"))

model.compile(loss="sparse_categorical_crossentropy",
            optimizer="adam",
            metrics=["accuracy"])

model.fit(X, y, batch_size=128, epochs=100, verbose=2, validation_split=0.3)
# Out:
# Epoch 1/100
# 85/85 - 27s - loss: 2.1687 - accuracy: 0.3678 - val_loss: 1.8022 - val_accuracy: 0.4131 - 27s/epoch - 316ms/step
# Epoch 2/100
# 85/85 - 22s - loss: 1.7155 - accuracy: 0.4483 - val_loss: 1.6353 - val_accuracy: 0.4672 - 22s/epoch - 263ms/step
# Epoch 3/100
# 85/85 - 20s - loss: 1.5265 - accuracy: 0.4995 - val_loss: 1.4637 - val_accuracy: 0.5201 - 20s/epoch - 240ms/step
# Epoch 4/100
# 85/85 - 22s - loss: 1.3930 - accuracy: 0.5473 - val_loss: 1.3764 - val_accuracy: 0.5521 - 22s/epoch - 254ms/step
# Epoch 5/100
# 85/85 - 22s - loss: 1.3285 - accuracy: 0.5676 - val_loss: 1.3373 - val_accuracy: 0.5635 - 22s/epoch - 254ms/step
# Epoch 6/100
# 85/85 - 20s - loss: 1.2870 - accuracy: 0.5822 - val_loss: 1.2848 - val_accuracy: 0.5772 - 20s/epoch - 237ms/step
# Epoch 7/100
# 85/85 - 19s - loss: 1.2235 - accuracy: 0.5996 - val_loss: 1.2191 - val_accuracy: 0.5979 - 19s/epoch - 222ms/step
# Epoch 8/100
# 85/85 - 18s - loss: 1.1960 - accuracy: 0.6038 - val_loss: 1.2121 - val_accuracy: 0.6013 - 18s/epoch - 217ms/step
# Epoch 9/100
# 85/85 - 19s - loss: 1.1446 - accuracy: 0.6215 - val_loss: 1.2288 - val_accuracy: 0.6062 - 19s/epoch - 219ms/step
# Epoch 10/100
# 85/85 - 19s - loss: 1.1136 - accuracy: 0.6366 - val_loss: 1.1587 - val_accuracy: 0.6266 - 19s/epoch - 223ms/step
# Epoch 11/100
# 85/85 - 19s - loss: 1.0633 - accuracy: 0.6500 - val_loss: 1.1318 - val_accuracy: 0.6299 - 19s/epoch - 223ms/step
# Epoch 12/100
# 85/85 - 18s - loss: 1.0296 - accuracy: 0.6622 - val_loss: 1.0907 - val_accuracy: 0.6462 - 18s/epoch - 214ms/step
# Epoch 13/100
# 85/85 - 19s - loss: 1.0038 - accuracy: 0.6736 - val_loss: 1.1782 - val_accuracy: 0.6258 - 19s/epoch - 224ms/step
# Epoch 14/100
# 85/85 - 18s - loss: 0.9653 - accuracy: 0.6832 - val_loss: 1.1080 - val_accuracy: 0.6359 - 18s/epoch - 215ms/step
# Epoch 15/100
# 85/85 - 20s - loss: 0.9437 - accuracy: 0.6882 - val_loss: 1.0607 - val_accuracy: 0.6552 - 20s/epoch - 235ms/step
# Epoch 16/100
# 85/85 - 20s - loss: 0.9062 - accuracy: 0.7021 - val_loss: 1.0535 - val_accuracy: 0.6591 - 20s/epoch - 241ms/step
# Epoch 17/100
# 85/85 - 20s - loss: 0.8866 - accuracy: 0.7058 - val_loss: 1.0478 - val_accuracy: 0.6612 - 20s/epoch - 239ms/step
# Epoch 18/100
# 85/85 - 22s - loss: 0.8469 - accuracy: 0.7269 - val_loss: 1.0312 - val_accuracy: 0.6660 - 22s/epoch - 256ms/step
# Epoch 19/100
# 85/85 - 21s - loss: 0.8233 - accuracy: 0.7265 - val_loss: 1.0621 - val_accuracy: 0.6623 - 21s/epoch - 246ms/step
# Epoch 20/100
# 85/85 - 21s - loss: 0.7939 - accuracy: 0.7359 - val_loss: 1.0435 - val_accuracy: 0.6649 - 21s/epoch - 245ms/step
# Epoch 21/100
# 85/85 - 21s - loss: 0.7820 - accuracy: 0.7428 - val_loss: 1.0596 - val_accuracy: 0.6623 - 21s/epoch - 246ms/step
# Epoch 22/100
# 85/85 - 22s - loss: 0.7517 - accuracy: 0.7584 - val_loss: 1.0335 - val_accuracy: 0.6718 - 22s/epoch - 258ms/step
# Epoch 23/100
# 85/85 - 24s - loss: 0.7221 - accuracy: 0.7667 - val_loss: 1.0636 - val_accuracy: 0.6632 - 24s/epoch - 280ms/step
# Epoch 24/100
# 85/85 - 20s - loss: 0.7040 - accuracy: 0.7743 - val_loss: 1.0413 - val_accuracy: 0.6651 - 20s/epoch - 239ms/step
# Epoch 25/100
# 85/85 - 20s - loss: 0.6938 - accuracy: 0.7763 - val_loss: 1.0639 - val_accuracy: 0.6614 - 20s/epoch - 237ms/step
# Epoch 26/100
# 85/85 - 22s - loss: 0.6679 - accuracy: 0.7838 - val_loss: 1.0879 - val_accuracy: 0.6657 - 22s/epoch - 257ms/step
# Epoch 27/100
# 85/85 - 21s - loss: 0.6397 - accuracy: 0.7969 - val_loss: 1.0393 - val_accuracy: 0.6765 - 21s/epoch - 246ms/step
# Epoch 28/100
# 85/85 - 21s - loss: 0.6238 - accuracy: 0.7979 - val_loss: 1.0930 - val_accuracy: 0.6541 - 21s/epoch - 249ms/step
# Epoch 29/100
# 85/85 - 24s - loss: 0.5974 - accuracy: 0.8072 - val_loss: 1.0308 - val_accuracy: 0.6844 - 24s/epoch - 286ms/step
# Epoch 30/100
# 85/85 - 26s - loss: 0.5731 - accuracy: 0.8192 - val_loss: 1.0460 - val_accuracy: 0.6823 - 26s/epoch - 301ms/step
# Epoch 31/100
# 85/85 - 23s - loss: 0.5517 - accuracy: 0.8213 - val_loss: 1.0281 - val_accuracy: 0.6773 - 23s/epoch - 267ms/step
# Epoch 32/100
# 85/85 - 22s - loss: 0.5289 - accuracy: 0.8336 - val_loss: 1.0639 - val_accuracy: 0.6814 - 22s/epoch - 262ms/step
# Epoch 33/100
# 85/85 - 24s - loss: 0.5007 - accuracy: 0.8375 - val_loss: 1.0526 - val_accuracy: 0.6810 - 24s/epoch - 277ms/step
# Epoch 34/100
# 85/85 - 23s - loss: 0.4891 - accuracy: 0.8450 - val_loss: 1.0650 - val_accuracy: 0.6784 - 23s/epoch - 272ms/step
# Epoch 35/100
# 85/85 - 23s - loss: 0.4713 - accuracy: 0.8508 - val_loss: 1.0936 - val_accuracy: 0.6718 - 23s/epoch - 276ms/step
# Epoch 36/100
# 85/85 - 24s - loss: 0.4441 - accuracy: 0.8618 - val_loss: 1.1616 - val_accuracy: 0.6683 - 24s/epoch - 278ms/step
# Epoch 37/100
# 85/85 - 26s - loss: 0.4187 - accuracy: 0.8704 - val_loss: 1.0936 - val_accuracy: 0.6861 - 26s/epoch - 304ms/step
# Epoch 38/100
# 85/85 - 24s - loss: 0.4005 - accuracy: 0.8750 - val_loss: 1.1033 - val_accuracy: 0.6861 - 24s/epoch - 277ms/step
# Epoch 39/100
# 85/85 - 23s - loss: 0.3724 - accuracy: 0.8869 - val_loss: 1.1624 - val_accuracy: 0.6685 - 23s/epoch - 271ms/step
# Epoch 40/100
# 85/85 - 23s - loss: 0.3625 - accuracy: 0.8860 - val_loss: 1.1532 - val_accuracy: 0.6803 - 23s/epoch - 276ms/step
# Epoch 41/100
# 85/85 - 25s - loss: 0.3468 - accuracy: 0.8913 - val_loss: 1.2101 - val_accuracy: 0.6707 - 25s/epoch - 293ms/step
# Epoch 42/100
# 85/85 - 25s - loss: 0.3503 - accuracy: 0.8913 - val_loss: 1.1728 - val_accuracy: 0.6810 - 25s/epoch - 290ms/step
# Epoch 43/100
# 85/85 - 25s - loss: 0.3091 - accuracy: 0.9051 - val_loss: 1.2229 - val_accuracy: 0.6763 - 25s/epoch - 291ms/step
# Epoch 44/100
# 85/85 - 23s - loss: 0.2937 - accuracy: 0.9099 - val_loss: 1.2445 - val_accuracy: 0.6668 - 23s/epoch - 273ms/step
# Epoch 45/100
# 85/85 - 23s - loss: 0.2791 - accuracy: 0.9169 - val_loss: 1.2248 - val_accuracy: 0.6791 - 23s/epoch - 269ms/step
# Epoch 46/100
# 85/85 - 25s - loss: 0.2562 - accuracy: 0.9236 - val_loss: 1.2544 - val_accuracy: 0.6791 - 25s/epoch - 290ms/step
# Epoch 47/100
# 85/85 - 27s - loss: 0.2464 - accuracy: 0.9268 - val_loss: 1.2974 - val_accuracy: 0.6683 - 27s/epoch - 313ms/step
# Epoch 48/100
# 85/85 - 29s - loss: 0.2399 - accuracy: 0.9283 - val_loss: 1.2925 - val_accuracy: 0.6823 - 29s/epoch - 342ms/step
# Epoch 49/100
# 85/85 - 32s - loss: 0.2132 - accuracy: 0.9397 - val_loss: 1.3075 - val_accuracy: 0.6827 - 32s/epoch - 374ms/step
# Epoch 50/100
# 85/85 - 28s - loss: 0.2114 - accuracy: 0.9387 - val_loss: 1.4009 - val_accuracy: 0.6765 - 28s/epoch - 334ms/step
# Epoch 51/100
# 85/85 - 29s - loss: 0.1953 - accuracy: 0.9454 - val_loss: 1.3938 - val_accuracy: 0.6758 - 29s/epoch - 339ms/step
# Epoch 52/100
# 85/85 - 26s - loss: 0.2019 - accuracy: 0.9396 - val_loss: 1.4032 - val_accuracy: 0.6773 - 26s/epoch - 309ms/step
# Epoch 53/100
# 85/85 - 25s - loss: 0.1761 - accuracy: 0.9517 - val_loss: 1.4031 - val_accuracy: 0.6752 - 25s/epoch - 293ms/step
# Epoch 54/100
# 85/85 - 22s - loss: 0.1498 - accuracy: 0.9634 - val_loss: 1.4509 - val_accuracy: 0.6763 - 22s/epoch - 261ms/step
# Epoch 55/100
# 85/85 - 22s - loss: 0.1430 - accuracy: 0.9625 - val_loss: 1.4655 - val_accuracy: 0.6756 - 22s/epoch - 253ms/step
# Epoch 56/100
# 85/85 - 23s - loss: 0.1286 - accuracy: 0.9700 - val_loss: 1.4838 - val_accuracy: 0.6793 - 23s/epoch - 266ms/step
# Epoch 57/100
# 85/85 - 22s - loss: 0.1303 - accuracy: 0.9664 - val_loss: 1.5134 - val_accuracy: 0.6782 - 22s/epoch - 263ms/step
# Epoch 58/100
# 85/85 - 24s - loss: 0.1199 - accuracy: 0.9700 - val_loss: 1.5795 - val_accuracy: 0.6653 - 24s/epoch - 281ms/step
# Epoch 59/100
# 85/85 - 24s - loss: 0.1294 - accuracy: 0.9643 - val_loss: 1.7210 - val_accuracy: 0.6660 - 24s/epoch - 286ms/step
# Epoch 60/100
# 85/85 - 25s - loss: 0.1152 - accuracy: 0.9707 - val_loss: 1.6039 - val_accuracy: 0.6778 - 25s/epoch - 296ms/step
# Epoch 61/100
# 85/85 - 24s - loss: 0.0884 - accuracy: 0.9812 - val_loss: 1.6531 - val_accuracy: 0.6715 - 24s/epoch - 284ms/step
# Epoch 62/100
# 85/85 - 24s - loss: 0.0867 - accuracy: 0.9790 - val_loss: 1.7161 - val_accuracy: 0.6644 - 24s/epoch - 283ms/step
# Epoch 63/100
# 85/85 - 24s - loss: 0.0786 - accuracy: 0.9823 - val_loss: 1.7170 - val_accuracy: 0.6788 - 24s/epoch - 282ms/step
# Epoch 64/100
# 85/85 - 22s - loss: 0.0772 - accuracy: 0.9825 - val_loss: 1.7634 - val_accuracy: 0.6690 - 22s/epoch - 254ms/step
# Epoch 65/100
# 85/85 - 22s - loss: 0.0650 - accuracy: 0.9881 - val_loss: 1.7862 - val_accuracy: 0.6653 - 22s/epoch - 260ms/step
# Epoch 66/100
# 85/85 - 23s - loss: 0.0594 - accuracy: 0.9893 - val_loss: 1.8000 - val_accuracy: 0.6756 - 23s/epoch - 268ms/step
# Epoch 67/100
# 85/85 - 22s - loss: 0.0579 - accuracy: 0.9896 - val_loss: 1.8128 - val_accuracy: 0.6797 - 22s/epoch - 255ms/step
# Epoch 68/100
# 85/85 - 22s - loss: 0.0472 - accuracy: 0.9931 - val_loss: 1.8951 - val_accuracy: 0.6653 - 22s/epoch - 263ms/step
# Epoch 69/100
# 85/85 - 24s - loss: 0.0526 - accuracy: 0.9906 - val_loss: 1.8708 - val_accuracy: 0.6745 - 24s/epoch - 282ms/step
# Epoch 70/100
# 85/85 - 23s - loss: 0.0663 - accuracy: 0.9855 - val_loss: 1.9166 - val_accuracy: 0.6733 - 23s/epoch - 266ms/step
# Epoch 71/100
# 85/85 - 24s - loss: 0.0429 - accuracy: 0.9930 - val_loss: 1.9421 - val_accuracy: 0.6752 - 24s/epoch - 279ms/step
# Epoch 72/100
# 85/85 - 24s - loss: 0.0423 - accuracy: 0.9922 - val_loss: 1.9633 - val_accuracy: 0.6647 - 24s/epoch - 283ms/step
# Epoch 73/100
# 85/85 - 25s - loss: 0.0515 - accuracy: 0.9891 - val_loss: 2.0485 - val_accuracy: 0.6677 - 25s/epoch - 296ms/step
# Epoch 74/100
# 85/85 - 23s - loss: 0.0428 - accuracy: 0.9922 - val_loss: 2.0099 - val_accuracy: 0.6694 - 23s/epoch - 267ms/step
# Epoch 75/100
# 85/85 - 23s - loss: 0.0336 - accuracy: 0.9945 - val_loss: 2.0079 - val_accuracy: 0.6743 - 23s/epoch - 271ms/step
# Epoch 76/100
# 85/85 - 26s - loss: 0.0241 - accuracy: 0.9971 - val_loss: 2.1004 - val_accuracy: 0.6741 - 26s/epoch - 305ms/step
# Epoch 77/100
# 85/85 - 22s - loss: 0.0318 - accuracy: 0.9952 - val_loss: 2.1304 - val_accuracy: 0.6767 - 22s/epoch - 255ms/step
# Epoch 78/100
# 85/85 - 20s - loss: 0.0260 - accuracy: 0.9965 - val_loss: 2.1616 - val_accuracy: 0.6640 - 20s/epoch - 231ms/step
# Epoch 79/100
# 85/85 - 19s - loss: 0.0543 - accuracy: 0.9855 - val_loss: 2.2367 - val_accuracy: 0.6660 - 19s/epoch - 227ms/step
# Epoch 80/100
# 85/85 - 19s - loss: 0.0452 - accuracy: 0.9884 - val_loss: 2.2237 - val_accuracy: 0.6638 - 19s/epoch - 228ms/step
# Epoch 81/100
# 85/85 - 19s - loss: 0.0340 - accuracy: 0.9926 - val_loss: 2.1655 - val_accuracy: 0.6664 - 19s/epoch - 225ms/step
# Epoch 82/100
# 85/85 - 19s - loss: 0.0276 - accuracy: 0.9951 - val_loss: 2.3397 - val_accuracy: 0.6760 - 19s/epoch - 225ms/step
# Epoch 83/100
# 85/85 - 21s - loss: 0.0577 - accuracy: 0.9836 - val_loss: 2.2746 - val_accuracy: 0.6528 - 21s/epoch - 253ms/step
# Epoch 84/100
# 85/85 - 27s - loss: 0.0468 - accuracy: 0.9857 - val_loss: 2.2900 - val_accuracy: 0.6627 - 27s/epoch - 313ms/step
# Epoch 85/100
# 85/85 - 34s - loss: 0.0326 - accuracy: 0.9924 - val_loss: 2.3309 - val_accuracy: 0.6700 - 34s/epoch - 405ms/step
# Epoch 86/100
# 85/85 - 27s - loss: 0.0222 - accuracy: 0.9962 - val_loss: 2.3794 - val_accuracy: 0.6720 - 27s/epoch - 314ms/step
# Epoch 87/100
# 85/85 - 21s - loss: 0.0125 - accuracy: 0.9986 - val_loss: 2.3081 - val_accuracy: 0.6803 - 21s/epoch - 252ms/step
# Epoch 88/100
# 85/85 - 22s - loss: 0.0091 - accuracy: 0.9993 - val_loss: 2.3736 - val_accuracy: 0.6756 - 22s/epoch - 257ms/step
# Epoch 89/100
# 85/85 - 22s - loss: 0.0093 - accuracy: 0.9994 - val_loss: 2.4082 - val_accuracy: 0.6666 - 22s/epoch - 259ms/step
# Epoch 90/100
# 85/85 - 25s - loss: 0.0099 - accuracy: 0.9988 - val_loss: 2.3784 - val_accuracy: 0.6793 - 25s/epoch - 296ms/step
# Epoch 91/100
# 85/85 - 26s - loss: 0.0079 - accuracy: 0.9993 - val_loss: 2.3959 - val_accuracy: 0.6720 - 26s/epoch - 304ms/step
# Epoch 92/100
# 85/85 - 21s - loss: 0.0078 - accuracy: 0.9996 - val_loss: 2.4151 - val_accuracy: 0.6758 - 21s/epoch - 248ms/step
# Epoch 93/100
# 85/85 - 20s - loss: 0.0076 - accuracy: 0.9994 - val_loss: 2.4629 - val_accuracy: 0.6735 - 20s/epoch - 233ms/step
# Epoch 94/100
# 85/85 - 20s - loss: 0.0075 - accuracy: 0.9993 - val_loss: 2.4453 - val_accuracy: 0.6776 - 20s/epoch - 230ms/step
# Epoch 95/100
# 85/85 - 20s - loss: 0.0076 - accuracy: 0.9993 - val_loss: 2.5340 - val_accuracy: 0.6687 - 20s/epoch - 235ms/step
# Epoch 96/100
# 85/85 - 20s - loss: 0.0094 - accuracy: 0.9990 - val_loss: 2.5556 - val_accuracy: 0.6793 - 20s/epoch - 238ms/step
# Epoch 97/100
# 85/85 - 21s - loss: 0.1355 - accuracy: 0.9594 - val_loss: 2.6405 - val_accuracy: 0.6348 - 21s/epoch - 247ms/step
# Epoch 98/100
# 85/85 - 22s - loss: 0.2033 - accuracy: 0.9323 - val_loss: 2.4522 - val_accuracy: 0.6580 - 22s/epoch - 254ms/step
# Epoch 99/100
# 85/85 - 20s - loss: 0.0511 - accuracy: 0.9847 - val_loss: 2.4533 - val_accuracy: 0.6623 - 20s/epoch - 241ms/step
# Epoch 100/100
# 85/85 - 23s - loss: 0.0180 - accuracy: 0.9978 - val_loss: 2.3994 - val_accuracy: 0.6776 - 23s/epoch - 267ms/step

# %%
model.save("GarbageClassifier.model")
# Out:
# INFO:tensorflow:Assets written to: GarbageClassifier.model\assets
